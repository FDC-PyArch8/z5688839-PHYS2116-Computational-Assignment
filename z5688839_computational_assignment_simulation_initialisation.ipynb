# %% [markdown]
# <a href="https://colab.research.google.com/github/FDC-PyArch8/z5688839-PHYS2116-Computational-Assignment/blob/main/z5688839_computational_assignment_simulation_initialisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install rebound
# Out:
# Collecting rebound
#   Downloading rebound-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Downloading rebound-4.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (830 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.6/830.6 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: rebound
# Successfully installed rebound-4.6.0

# %%
import rebound
import math

# %%
# test simulation of sun and Earth-mass planet

# initialising simulation
sim_sun = rebound.Simulation()

# formatting the value of G to fit the units below
sim_sun.units = ('yr', 'AU', 'Msun')
print("G = {0}.".format(sim_sun.G))

# adding particles of mass m and semi-major axis a
sim_sun.add(m=1.0)
sim_sun.add(m=1.0e-3, a=1.0)

#integrating orbit
sim_sun.integrate(10000)
orbits = sim_sun.orbits()
for o in orbits:
    print(o.a, o.e)
# Out:
# G = 39.476926421373.
# 0.9999999999999114 1.81309768997835e-13

# %%
# initialising orbit of an equal-mass binary star system
sim_two_body = rebound.Simulation()
sim_two_body.units = ('yr', 'AU', 'Msun')
print("G = {0}.".format(sim_two_body.G))

# adding particles with x-position x and y-velocity vy
sim_two_body.add(m=1.0)
sim_two_body.add(m=1.0, x=1, vy=1)
sim_two_body.status()

# integrating for 8000 years with timesteps of 1 yr
sim_two_body.integrate(8000)

# setting centre of mass at 0 to reduce numerical error
sim_two_body.move_to_com()
sim_two_body.status()
orbits = sim_two_body.orbits()
for o in orbits:
    print(o.a, o.e)
# Out:
# G = 39.476926421373.
# ---------------------------------
# REBOUND version:     	4.6.0
# REBOUND built on:    	Feb 11 2026 17:35:06
# Number of particles: 	2
# Selected integrator: 	ias15
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.001000
# ---------------------------------
# <rebound.particle.Particle object at 0x78c79439c650, m=1.0 x=0.0 y=0.0 z=0.0 vx=0.0 vy=0.0 vz=0.0>
# <rebound.particle.Particle object at 0x78c79439c8d0, m=1.0 x=1.0 y=0.0 z=0.0 vx=0.0 vy=1.0 vz=0.0>
# ---------------------------------
# The following fields have non-default values:
# G:
# < 1.000000e+00
# ---
# > 3.947693e+01
# N:
# < 0
# ---
# > 2
# python_unit_l:
# < 0
# ---
# > 12937928
# python_unit_m:
# < 0
# ---
# > 2145773914
# python_unit_t:
# < 0
# ---
# > 1864791206
# rand_seed:
# < 573678
# ---
# > 569497
# particles:
# > (256 bytes, values not printed)
#
# ---------------------------------
# REBOUND version:     	4.6.0
# REBOUND built on:    	Feb 11 2026 17:35:06
# Number of particles: 	2
# Selected integrator: 	ias15
# Simulation time:     	8.0000000000000000e+03
# Current timestep:    	0.011956
# ---------------------------------
# <rebound.particle.Particle object at 0x78c79439c650, m=1.0 x=-0.4891221675291725 y=0.011610174365614512 z=0.0 vx=-0.9367903760119689 vy=-0.4888833833953131 vz=0.0>
# <rebound.particle.Particle object at 0x78c79439c450, m=1.0 x=0.4891221675291725 y=-0.011610174366069259 z=0.0 vx=0.9367903760119689 vy=0.4888833833953131 vz=0.0>
# ---------------------------------
# The following fields have non-default values:
# t:
# < 0.000000e+00
# ---
# > 8.000000e+03
# G:
# < 1.000000e+00
# ---
# > 3.947693e+01
# dt:
# < 1.000000e-03
# ---
# > 1.195625e-02
# N:
# < 0
# ---
# > 2
# walltime:
# < 0.000000e+00
# ---
# > 3.034589e+01
# walltime_last_steps:
# < 0.000000e+00
# ---
# > 6.062076e-06
# python_unit_l:
# < 0
# ---
# > 12937928
# python_unit_m:
# < 0
# ---
# > 2145773914
# python_unit_t:
# < 0
# ---
# > 1864791206
# steps_done:
# < 0
# ---
# > 4847657
# dt_last_done:
# < 0.000000e+00
# ---
# > 1.443895e-02
# rand_seed:
# < 176672
# ---
# > 569497
# particles:
# > (256 bytes, values not printed)
# ri_ias15.at:
# > (48 bytes, values not printed)
# ri_ias15.x0:
# > (48 bytes, values not printed)
# ri_ias15.v0:
# > (48 bytes, values not printed)
# ri_ias15.a0:
# > (48 bytes, values not printed)
# ri_ias15.csx:
# > (48 bytes, values not printed)
# ri_ias15.csv:
# > (48 bytes, values not printed)
# ri_ias15.csa0:
# > (48 bytes, values not printed)
# ri_ias15.g:
# > (336 bytes, values not printed)
# ri_ias15.b:
# > (336 bytes, values not printed)
# ri_ias15.csb:
# > (336 bytes, values not printed)
# ri_ias15.e:
# > (336 bytes, values not printed)
# ri_ias15.br:
# > (336 bytes, values not printed)
# ri_ias15.er:
# > (336 bytes, values not printed)
#
# 0.5031865854837406 0.9873343736317732

# %%
op = rebound.OrbitPlotSet(sim_two_body)
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
# parsec = au / arcsec
def au(arcsec):
  distance_parsecs = 1.34
  au = distance_parsecs * arcsec
  return au

def radians(degrees):
    return degrees * (math.pi / 180)

# %%
au(17.4930)
# Out:
# 23.44062

# %%
# initialising the simulation and setting a value for G which gives the below units
sim_centauri = rebound.Simulation()
sim_centauri.units = ('yr', 'AU', 'Msun')
print("G = {0}.".format(sim_centauri.G))

# initialising trinary system by adding particles
sim_centauri.add(m=1.0788, hash="cen_a")
sim_centauri.add(m=0.9092, a=23.3, e=0.51947, inc=radians(79.2430),
                 Omega=radians(205.073), omega=radians(231.519), T=1955.564, hash="cen_b")
sim_centauri.add(m=0.122, a=8.2e3, e=0.497, inc=radians(124.9),
                 Omega=radians(165), omega=radians(151.0), T=278e3,
                 hash="prox_cen")
sim_centauri.status()

#references: https://www.mdpi.com/2218-1997/10/2/64,
#            https://iopscience.iop.org/article/10.3847/1538-3881/abfaff/pdf
#            https://www.stellarcatalog.com/stars/proxima-centauri

sim_centauri.integrate(1000)
sim_centauri.move_to_com()  # setting centre of mass at 0 to reduce numerical error
sim_centauri.status()
orbits = sim_centauri.orbits()
# Out:
# G = 39.476926421373.
# ---------------------------------
# REBOUND version:     	4.6.0
# REBOUND built on:    	Feb 11 2026 17:35:06
# Number of particles: 	3
# Selected integrator: 	ias15
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.001000
# ---------------------------------
# <rebound.particle.Particle object at 0x78c7942ef950, m=1.0788 x=0.0 y=0.0 z=0.0 vx=0.0 vy=0.0 vz=0.0>
# <rebound.particle.Particle object at 0x78c7942a7750, m=0.9092 x=-18.696523979377055 y=-14.28867265104223 z=26.419040799861133 vx=0.7430779931127516 vy=0.20312296253892428 vz=0.6890830002453935>
# <rebound.particle.Particle object at 0x78c7942ef950, m=0.122 x=-10691.342594613147 y=-1304.7679124414537 z=-5748.885259890657 vx=0.3089037306841255 vy=0.12754657943143172 vz=0.35164601179503097>
# ---------------------------------
# The following fields have non-default values:
# G:
# < 1.000000e+00
# ---
# > 3.947693e+01
# N:
# < 0
# ---
# > 3
# python_unit_l:
# < 0
# ---
# > 12937928
# python_unit_m:
# < 0
# ---
# > 2145773914
# python_unit_t:
# < 0
# ---
# > 1864791206
# rand_seed:
# < 604341
# ---
# > 602164
# particles:
# > (384 bytes, values not printed)
#
# ---------------------------------
# REBOUND version:     	4.6.0
# REBOUND built on:    	Feb 11 2026 17:35:06
# Number of particles: 	3
# Selected integrator: 	ias15
# Simulation time:     	1.0000000000000000e+03
# Current timestep:    	0.526843
# ---------------------------------
# <rebound.particle.Particle object at 0x78c7942ef950, m=1.0788 x=618.912291862956 y=71.73115380044071 z=336.1039013487735 vx=1.2761988202346377 vy=0.48879550713694986 vz=0.5006509127546444>
# <rebound.particle.Particle object at 0x78c7942a7750, m=0.9092 x=620.0939728058802 y=74.63362049699737 z=324.90182167397 vx=-1.5104083817928247 vy=-0.5843622432798117 vz=-0.5986886400739873>
# <rebound.particle.Particle object at 0x78c7942ef950, m=0.122 x=-10094.03295522019 y=-1190.4955448834871 z=-5393.357582303527 vx=-0.028688414287632524 vy=0.032701299103797404 vz=0.034635302258678835>
# ---------------------------------
# The following fields have non-default values:
# t:
# < 0.000000e+00
# ---
# > 1.000000e+03
# G:
# < 1.000000e+00
# ---
# > 3.947693e+01
# dt:
# < 1.000000e-03
# ---
# > 5.268428e-01
# N:
# < 0
# ---
# > 3
# walltime:
# < 0.000000e+00
# ---
# > 8.458000e-03
# python_unit_l:
# < 0
# ---
# > 12937928
# python_unit_m:
# < 0
# ---
# > 2145773914
# python_unit_t:
# < 0
# ---
# > 1864791206
# steps_done:
# < 0
# ---
# > 664
# dt_last_done:
# < 0.000000e+00
# ---
# > 1.403131e-01
# rand_seed:
# < 613644
# ---
# > 602164
# particles:
# > (384 bytes, values not printed)
# ri_ias15.at:
# > (72 bytes, values not printed)
# ri_ias15.x0:
# > (72 bytes, values not printed)
# ri_ias15.v0:
# > (72 bytes, values not printed)
# ri_ias15.a0:
# > (72 bytes, values not printed)
# ri_ias15.csx:
# > (72 bytes, values not printed)
# ri_ias15.csv:
# > (72 bytes, values not printed)
# ri_ias15.csa0:
# > (72 bytes, values not printed)
# ri_ias15.g:
# > (504 bytes, values not printed)
# ri_ias15.b:
# > (504 bytes, values not printed)
# ri_ias15.csb:
# > (504 bytes, values not printed)
# ri_ias15.e:
# > (504 bytes, values not printed)
# ri_ias15.br:
# > (504 bytes, values not printed)
# ri_ias15.er:
# > (504 bytes, values not printed)

# %%
op3 = rebound.OrbitPlotSet(sim_centauri)
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
# attempt at an animation
op = rebound.OrbitPlot(sim_centauri)
fig = op.fig
for i in range(3):
    sim_centauri.integrate(sim_centauri.t+0.31)
    op1.update()
    op2.update()
    op1.fig.savefig("out_%02d.png"%i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2205/99746420.py in <cell line: 0>()
#       1 # attempt at an animation
# ----> 2 op = rebound.OrbitPlot(sim_centauri)
#       3 fig = op.fig
#       4 for i in range(3):
#       5     sim_centauri.integrate(sim_centauri.t+0.31)
#
# NameError: name 'rebound' is not defined
